# %%
import pandas as pd
import numpy as np
import operator
import warnings
import re
warnings.filterwarnings('ignore')

import nltk
from nltk.stem import WordNetLemmatizer
nltk.download('stopwords')
nltk.download('wordnet')

from nltk.corpus import stopwords
from statistics import mean 

from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import f1_score,jaccard_score
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.model_selection import RepeatedKFold 
from sklearn.model_selection import GridSearchCV
from sklearn.decomposition import LatentDirichletAllocation
# Out:
# [nltk_data] Downloading package stopwords to /Users/timur/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/timur/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Извлечение данных

# %%
app_list = ["facebook", "swiftkey", "tapfish", "templerun2"]
labeled_df_path ="Diplom/{}_labeled.csv"
unlabeled_df_path ="Diplom/{}_unlabeled.csv"

TEXT = "text"
RATING = "rating"
INFORMATIVE = "informative"

DIVIDER = "\n-----------------------------------------------------------------\n"

# %%
def get_labeled_df_from_app(app):
    return pd.read_csv(labeled_df_path.format(app))

def get_unlabeled_df_from_app(app):
    return pd.read_csv(unlabeled_df_path.format(app))

def get_all_apps_labeled_df():
    sum_df = pd.DataFrame(columns=[TEXT, RATING, INFORMATIVE])
    for app in app_list:
        l_df = get_labeled_df_from_app(app)
        sum_df = pd.concat([
            sum_df,l_df
        ],ignore_index=True)
    return sum_df

def get_all_apps_unlabeled_df():
    sum_df = pd.DataFrame(columns=[TEXT, RATING])
    for app in app_list:
        u_df = get_unlabeled_df_from_app(app)
        sum_df = pd.concat([
            sum_df,u_df
        ],ignore_index=True)
    return sum_df

# %% [markdown]
# # Фильтрация

# %% [markdown]
# ## Предобработка данных

# %%
def preprocessing(X):
    documents = []
    stemmer = WordNetLemmatizer()
    for sen in range(0, len(X)):
        # Remove all the special characters
        document = re.sub(r'\W', ' ', str(X[sen]))
    
        # Remove all single characters
        document = re.sub(r'\s+[a-zA-Z]\s+', ' ', document)
    
        # Substituting multiple spaces with single space
        document = re.sub(r'\s+', ' ', document, flags=re.I)

        # Removing prefixed 'b'
        document = re.sub(r'^b\s+', '', document)

        # Converting to Lowercase
        document = document.lower()

        # Lemmatization
        document = document.split()

        document = [stemmer.lemmatize(word) for word in document]
        document = ' '.join(document)

        documents.append(document)
    return documents

# %% [markdown]
# ## Векторизация

# %%
MAX_FEATURES = 1500
MIN_DF = 5
MAX_DF = 0.7

tfidf_vectorizer = TfidfVectorizer(max_features=MAX_FEATURES, min_df=MIN_DF, max_df=MAX_DF, stop_words=stopwords.words('english'))
count_vectorizer = CountVectorizer(max_features=MAX_FEATURES, min_df=MIN_DF, max_df=MAX_DF, stop_words=stopwords.words('english'))

def fit_count_vectorizer(vectorizer, raw_documents):
    clean_documents = preprocessing(raw_documents)
    count_vectorizer.fit(clean_documents)
    return clean_documents
    
def get_tf(clean_documents):
    tf = count_vectorizer.transform(clean_documents)
    return tf

def fit_tfidf_vectorizer(raw_documents):
    clean_documents = preprocessing(raw_documents)
    tfidf_vectorizer.fit(clean_documents)
    return clean_documents
    
def get_tfidf(clean_documents):
    tfidf = tfidf_vectorizer.transform(clean_documents)
    return tfidf

# %%
def get_tf_feature_names():
    return count_vectorizer.get_feature_names()


def get_tfidf_feature_names():
    return tfidf_vectorizer.get_feature_names()

# %% [markdown]
# ## Сравнение классификаторов

# %%
default_classifiers = [
    LogisticRegression(),
    LinearSVC(),
    DecisionTreeClassifier(),
    RandomForestClassifier(),
    GradientBoostingClassifier()
]

# %%
def print_score_by_classifier(classifier, score):
    print("----- {} ---- \n".format(classifier.__class__.__name__))
    print('F1 score:', score)
    print("\n")

# %%
def get_f1_scores_cross_validation(classifier, X, y):
    scores = []
    cv = RepeatedKFold(n_splits=10, n_repeats=5, random_state=None) 
    for train_index, test_index in cv.split(X):
        X_train, X_test, y_train, y_test = X[train_index], X[test_index], y[train_index], y[test_index]
        classifier.fit(X_train, y_train)
        Y_pred = classifier.predict(X_test)
        score = f1_score(y_test, Y_pred)
        scores.append(score)
        
    return scores

# %%
def get_X_Y():
    df = get_all_apps_labeled_df()   
    raw_reviews = df[TEXT]
    clean_reviews = fit_tfidf_vectorizer(raw_reviews)
    review_features = get_tfidf(clean_reviews)
    X = review_features
    Y = df[INFORMATIVE].astype('int')
    return X, Y

# %%
def print_classifiers_comparison_report(classifiers):
    X, Y = get_X_Y()
    classifier_scores = []
    for classifier in classifiers:
        scores_by_classifier = get_f1_scores_cross_validation(classifier, X, Y)
        mean_score = mean(scores_by_classifier)
        print_score_by_classifier(classifier, mean_score)
        classifier_scores.append(mean_score)
        
    max_index, max_score = max(enumerate(classifier_scores), key=operator.itemgetter(1))
    return classifiers[max_index], max_score

# %% [markdown]
# ## Полученные результаты

# %%
best_classifier, max_score = print_classifiers_comparison_report(default_classifiers)
print("----- Best classifier: {} with F1-score {}".format(
                                                best_classifier.__class__.__name__,
                                                max_score,
                                                ))
# Out:
# ----- LogisticRegression ----
#
# F1 score: 0.8198256670403109
#
#
# ----- LinearSVC ----
#
# F1 score: 0.8407720280211066
#
#
# ----- DecisionTreeClassifier ----
#
# F1 score: 0.7946606711745674
#
#
# ----- RandomForestClassifier ----
#
# F1 score: 0.8131067165228496
#
#
# ----- GradientBoostingClassifier ----
#
# F1 score: 0.6943551913858309
#
#
# ----- Best classifier: LinearSVC with F1-score 0.8407720280211066

# %% [markdown]
# ### Настроим параметры для RandomForestClassifier и GradientBoostingClassifier

# %%
def get_best_params_from_random_forest():
    estimator = RandomForestClassifier()
    param_grid = { 
                "n_estimators"      : [100,200,300],
                "max_features"      : ["auto", "sqrt", "log2"],
                "min_samples_split" : [2,4,8],
                "bootstrap": [True, False],
    }
    grid = GridSearchCV(estimator, param_grid, n_jobs=-1, cv=3)
    
    X, Y = get_X_Y()
    grid.fit(X, Y)
    return grid.best_params_["n_estimators"], grid.best_params_["max_features"], grid.best_params_["min_samples_split"], grid.best_params_["bootstrap"], 
    
def get_best_random_forest():
    n_estimators, max_features, min_samples_split, bootstrap = get_best_params_from_random_forest()
    return RandomForestClassifier(
        n_estimators = n_estimators,
        max_features = max_features, 
        min_samples_split = min_samples_split,
        bootstrap = bootstrap
    )

# %%
def get_best_gradient_boosting_params():
    estimator = GradientBoostingClassifier()
    param_grid = {
    'learning_rate': [0.1, 0.05, 0.02, 0.01],
    'max_depth': [4, 6, 8],
    'min_samples_leaf': [20, 50,100,150]
    }

    grid = GridSearchCV(estimator, param_grid, cv=3, n_jobs=-1)
    
    X, Y = get_X_Y()
    grid.fit(X, Y)
    return grid.best_params_["learning_rate"], grid.best_params_["max_depth"], grid.best_params_["min_samples_leaf"]
    

def get_best_gradient_boosting_classifier():
    learning_rate, max_depth, min_samples_leaf = get_best_gradient_boosting_params()
    return GradientBoostingClassifier(
        learning_rate = learning_rate,
        max_depth = max_depth,
        min_samples_leaf = min_samples_leaf
    )

# %%
tuned_classifiers = [
    LogisticRegression(),
    LinearSVC(),
    DecisionTreeClassifier(),
    get_best_random_forest(),
    get_best_gradient_boosting_classifier()
]

# %% [markdown]
# ## Новые результаты

# %%
best_classifier, max_score = print_classifiers_comparison_report(tuned_classifiers)
print("----- Best classifier: {} with F1-score {}".format(
                                                best_classifier.__class__.__name__,
                                                max_score,
                                                ))
# Out:
# ----- LogisticRegression ----
#
# F1 score: 0.8188646890812574
#
#
# ----- LinearSVC ----
#
# F1 score: 0.8419225660256778
#
#
# ----- DecisionTreeClassifier ----
#
# F1 score: 0.7942819573645123
#
#
# ----- RandomForestClassifier ----
#
# F1 score: 0.8439587844105666
#
#
# ----- GradientBoostingClassifier ----
#
# F1 score: 0.7628969075602122
#
#
# ----- Best classifier: RandomForestClassifier with F1-score 0.8439587844105666

# %% [markdown]
# # Тематическая модель

# %% [markdown]
# ### Получение датасета из неразмеченных данных с использованием классификатора

# %%
def predict_for_df(unlabeled_df, classifier):
    clean_reviews = preprocessing(unlabeled_df[TEXT])
    X_test = get_tfidf(clean_reviews)
    Y_pred = classifier.predict(X_test)
    return Y_pred
    
def filter_df(df):
    df = df[df[INFORMATIVE]==1]
    filtered_df = df.reset_index(drop=True)
    return filtered_df
    
def get_filtered_df_from_unlabeled_df(app_index, classifier, row_limit = -1):
    app = app_list[app_index]
    unlabeled_df = get_labeled_df_from_app(app)
    Y_pred = predict_for_df(unlabeled_df, classifier)
    
    predicted_df = unlabeled_df.copy()
    predicted_df[INFORMATIVE] = Y_pred
    
    filtered_df = filter_df(predicted_df)
    filtered_df = filtered_df.dropna()
    filtered_df = filtered_df.drop_duplicates(subset=TEXT)
    if row_limit != -1:
        return  filtered_df.sample(frac=1).reset_index(drop=True).head(row_limit)
    else:
        return filtered_df

# %%
filtered_df = get_filtered_df_from_unlabeled_df(
    app_index = 0, 
    classifier = best_classifier, 
    row_limit = 10000)

# %%
def get_filtered_df_from_labeled_df(app_index, row_limit = -1):
    app = app_list[app_index]
    labeled_df = get_labeled_df_from_app(app)

    filtered_df = filter_df(labeled_df)
    filtered_df = filtered_df.dropna()
    filtered_df = filtered_df.drop_duplicates(subset=TEXT)
    if row_limit != -1:
        return  filtered_df.sample(frac=1).reset_index(drop=True).head(row_limit)
    else:
        return filtered_df

# %%
filtered_df = get_filtered_df_from_labeled_df(
    app_index = 0, 
    row_limit = 10000)

# %% [markdown]
# ### Подготовка входных данных для тематического моделирования

# %%
raw_reviews = filtered_df[TEXT].tolist()
clean_reviews = preprocessing(filtered_df[TEXT])
reviews_rating = filtered_df[RATING].astype('int')

# %% [markdown]
# ## Выделение тем
#
# #### 1) Создание LDA модели, из которой мы получаем матрицы весов и признаков
# #### 2) Создание классов Тем и Отзывов из этих матриц
# #### 3) Ранжирование топиков
# #### 4) Ранжирование отзывов
# ###### 4.1) Удаление нерелевантных к теме отзывов
# Нерелевантные отзывы не проходят порог веса к этой теме
# ###### 4.2) Удаление дублирующихся по смыслу отзывов
# Дублирующие отзывы это те, которые по критерию превышают порог
# #### 5) Показ результата
# ###### 5.1) Показ номера темы и её ключевых слов
# ###### 5.2) Показ топ-отзывов по этой теме

# %% [markdown]
# ### LDA модель

# %%
FEATURES_NUMBER = 1500
TOPIC_NUMBER = 20

# %%
def get_lda_outputs(clean_reviews):
    vectorizer = CountVectorizer(max_df=0.95, min_df=2, max_features=1500, stop_words=stopwords.words('english'))
    tf = vectorizer.fit_transform(clean_reviews)
    feature_names = vectorizer.get_feature_names()

    lda_model = LatentDirichletAllocation(
        n_components=TOPIC_NUMBER, max_iter=5, 
        learning_method='online', learning_offset=50.,random_state=0
    ).fit(tf)

    lda_W = lda_model.transform(tf)
    lda_H = lda_model.components_
    
    return lda_H, lda_W, feature_names

# %%
lda_H, lda_W, feature_names = get_lda_outputs(clean_reviews)

# %% [markdown]
# ### Классы Тем и Отзывов

# %%
def get_jaccard_similarity(str1, str2):
    str1 = preprocessing([str1])
    str2 = preprocessing([str2])
    a = set(str1[0].split()) 
    b = set(str2[0].split())
    c = a.intersection(b)
    return float(len(c)) / (len(a) + len(b) - len(c))

# %%
class Review:
    review_id = 0
    text_review = ""
    
    proportion = 0
    proportion_feature_weight = 0
    
    rating = 0
    rating_feature_weight = 0
    
    duplicate_number = 0
    duplicate_feature_weight = 0
    
    review_score = 0
    
    def __init__(self, review_id, text_review, proportion, rating, 
                    proportion_feature_weight, rating_feature_weight, duplicate_feature_weight):
        self.review_id = review_id
        self.text_review = text_review
        self.proportion = proportion
        self.rating = rating
        self.duplicate_feature_weight = duplicate_feature_weight
        self.rating_feature_weight = rating_feature_weight
        self.proportion_feature_weight = proportion_feature_weight
        
    def calculate_review_score(self):
        self.review_score = self.duplicate_feature_weight * self.duplicate_number +\
                            self.proportion_feature_weight * self.proportion +\
                            self.rating_feature_weight * float(1)/self.rating

# %%
class Topic:
    topic_id = 0
    reviews = []
    volume = 0
    volume_feature_weight = 0 
    rating = 0
    rating_feature_weight = 0
    group_score = 0

    key_words = []
    top_reviews_indices = 0
    
    def __init__(self, topic_id, volume_feature_weight, rating_feature_weight):
        self.topic_id = topic_id
        self.volume_feature_weight = volume_feature_weight
        self.rating_feature_weight = rating_feature_weight
        
    def get_top_reviews(self, top_review_number = -1):
        top = top_review_number
        if top == -1:
            top = len(self.reviews)
        if top > len(self.reviews) - 1:
            top = len(self.reviews) - 1
        
        return self.reviews[0:top]
        
    def get_top_keywords(self, top_keywords_number = -1):
        top = top_keywords_number
        if top == -1:
            top = len(self.key_words)
        if top > len(self.key_words) - 1:
            top = len(self.key_words) - 1
        return self.key_words[0:top]
        
        return key_words[0:top_keywords_number]
    
    def eliminate_unrelated_reviews(self, alpha = 0.1):
        for review in self.reviews[:]:
            if review.proportion < alpha:
                self.reviews.remove(review)
                
                
    def calculate_volume(self):
        for review in self.reviews:
            self.volume += review.proportion
            
    def calculate_rating(self):
        denominator = 0
        for review in self.reviews:
            denominator += review.rating * review.proportion
        self.rating = float(self.volume) / denominator
        
    def calculate_group_score(self):
        self.group_score = self.volume_feature_weight * self.volume + self.rating_feature_weight * self.rating
    
    def remove_duplicates(self, beta):
        duplicate_ids_to_delete = []
        review_ids = self.get_review_ids()
        for i in range(0, len(review_ids)-1):
            review_id_i = review_ids[i]
            
            if review_id_i in duplicate_ids_to_delete:
                continue 
                
            for j in range(i+1, len(review_ids)-1):
                review_id_j = review_ids[j]
                
                if review_id_j in duplicate_ids_to_delete:
                    continue
                
                review_i = self.reviews[i]
                review_j = self.reviews[j]
                
                if get_jaccard_similarity(
                    review_i.text_review, 
                    review_j.text_review
                ) >= beta:

                    review_i.rating = min(review_i.rating, review_j.rating)
                    review_i.proportion = max(review_i.proportion, review_j.proportion)
                    review_i.duplicate_number += 1
                    duplicate_ids_to_delete.append(review_id_j)
                
    
        unique_review_list = [review for review in self.reviews if review.review_id not in duplicate_ids_to_delete]
        self.reviews = unique_review_list
    
    def print_review_ids(self):
        review_ids = self.get_review_ids()
        print(review_ids)
            
    def get_review_ids(self):
        review_ids = []
        for review in self.reviews:
            review_ids.append(review.review_id)
        return review_ids

# %% [markdown]
# ### Создание объектов Тем и Отзывов

# %%
def get_topic_list():
    topic_list = []
    for topic_idx, word_list in enumerate(lda_H):
        topic = Topic(topic_idx, volume_feature_weight = 0.7, rating_feature_weight = 0.3)
        topic.key_words = [feature_names[i] for i in word_list.argsort()[::-1]]
        review_proportions = lda_W[:,topic_idx]

        review_list = []
        for review_id in range(0, len(reviews_rating)):
            review = Review(review_id, raw_reviews[review_id], review_proportions[review_id], reviews_rating[review_id],
                            proportion_feature_weight = 0.4, rating_feature_weight = 0.2, duplicate_feature_weight = 0.4)
            review_list.append(review)

        topic.reviews = review_list
        topic_list.append(topic)
    return topic_list

# %% [markdown]
# ### Ранжирование Тем и Отзывов

# %%
def topics_ranking(topic_list):
    for topic in topic_list:
        topic.calculate_volume()
        topic.calculate_rating()
        topic.calculate_group_score()
        
    topic_list.sort(key=lambda topic: topic.group_score, reverse=True)

# %%
def reviews_ranking(topic_list, min_proportion_for_topic = 0.1, duplicate_similarity_score = 0.5):
    print(DIVIDER)
    for topic in topic_list:
        print('Topic {}: \n'.format(topic.topic_id))
        
        number_of_reviews = len(topic.reviews)
        print('Number of reviews: ', number_of_reviews)

        topic.eliminate_unrelated_reviews(min_proportion_for_topic)
        print('Unrelated eliminated: ', number_of_reviews - len(topic.reviews))

        number_of_reviews = len(topic.reviews)
        print('Number of reviews: ', number_of_reviews)

        topic.remove_duplicates(duplicate_similarity_score)
        print('Duplicate eliminated: ', number_of_reviews - len(topic.reviews))

        number_of_reviews = len(topic.reviews)
        print('Number of reviews: ', number_of_reviews)

        print(DIVIDER)
    
        for review in topic.reviews:
            review.calculate_review_score()
        
        topic.reviews.sort(key=lambda review: review.review_score, reverse=True)

# %%
def print_topics_with_reviews(topic_list):
    for topic in topic_list:
        print("Topic {}:\n\nKeywords: {}\n".format(
            topic.topic_id,
            (" ".join(topic.get_top_keywords(top_keywords_number = TOP_KEYWORDS_NUMBER)).upper())
        ))

        print("Top reviews from this topic:\n")
        for idx, review in enumerate(topic.get_top_reviews(top_review_number = TOP_REVIEWS_NUMBER)):
            print("{}) {}".format(idx, review.text_review, end=''))
            
        print(DIVIDER)

# %% [markdown]
# ### Результаты тематического моделирования

# %%
MIN_PROPORTION_FOR_TOPIC = 0.1
DUPLICATE_SIMILARITY_SCORE = 0.5

# %%
TOP_KEYWORDS_NUMBER = 5
TOP_REVIEWS_NUMBER = 20

# %%
topic_list = get_topic_list()

print("\n Topic and review ranking process: \n")
topics_ranking(topic_list)
reviews_ranking(
                topic_list, 
                min_proportion_for_topic = MIN_PROPORTION_FOR_TOPIC, 
                duplicate_similarity_score = DUPLICATE_SIMILARITY_SCORE)
# Out:
#  Topic and review ranking process:
#
#
# -----------------------------------------------------------------
#
# Topic 3:
#
# Number of reviews:  1661
# Unrelated eliminated:  1055
# Number of reviews:  606
# Duplicate eliminated:  33
# Number of reviews:  573
#
# -----------------------------------------------------------------
#
# Topic 9:
#
# Number of reviews:  1661
# Unrelated eliminated:  1110
# Number of reviews:  551
# Duplicate eliminated:  35
# Number of reviews:  516
#
# -----------------------------------------------------------------
#
# Topic 14:
#
# Number of reviews:  1661
# Unrelated eliminated:  1212
# Number of reviews:  449
# Duplicate eliminated:  22
# Number of reviews:  427
#
# -----------------------------------------------------------------
#
# Topic 2:
#
# Number of reviews:  1661
# Unrelated eliminated:  1286
# Number of reviews:  375
# Duplicate eliminated:  18
# Number of reviews:  357
#
# -----------------------------------------------------------------
#
# Topic 12:
#
# Number of reviews:  1661
# Unrelated eliminated:  1548
# Number of reviews:  113
# Duplicate eliminated:  5
# Number of reviews:  108
#
# -----------------------------------------------------------------
#
# Topic 10:
#
# Number of reviews:  1661
# Unrelated eliminated:  1560
# Number of reviews:  101
# Duplicate eliminated:  3
# Number of reviews:  98
#
# -----------------------------------------------------------------
#
# Topic 1:
#
# Number of reviews:  1661
# Unrelated eliminated:  1576
# Number of reviews:  85
# Duplicate eliminated:  0
# Number of reviews:  85
#
# -----------------------------------------------------------------
#
# Topic 11:
#
# Number of reviews:  1661
# Unrelated eliminated:  1598
# Number of reviews:  63
# Duplicate eliminated:  0
# Number of reviews:  63
#
# -----------------------------------------------------------------
#
# Topic 18:
#
# Number of reviews:  1661
# Unrelated eliminated:  1604
# Number of reviews:  57
# Duplicate eliminated:  0
# Number of reviews:  57
#
# -----------------------------------------------------------------
#
# Topic 7:
#
# Number of reviews:  1661
# Unrelated eliminated:  1610
# Number of reviews:  51
# Duplicate eliminated:  1
# Number of reviews:  50
#
# -----------------------------------------------------------------
#
# Topic 13:
#
# Number of reviews:  1661
# Unrelated eliminated:  1604
# Number of reviews:  57
# Duplicate eliminated:  3
# Number of reviews:  54
#
# -----------------------------------------------------------------
#
# Topic 0:
#
# Number of reviews:  1661
# Unrelated eliminated:  1611
# Number of reviews:  50
# Duplicate eliminated:  0
# Number of reviews:  50
#
# -----------------------------------------------------------------
#
# Topic 15:
#
# Number of reviews:  1661
# Unrelated eliminated:  1621
# Number of reviews:  40
# Duplicate eliminated:  0
# Number of reviews:  40
#
# -----------------------------------------------------------------
#
# Topic 6:
#
# Number of reviews:  1661
# Unrelated eliminated:  1620
# Number of reviews:  41
# Duplicate eliminated:  0
# Number of reviews:  41
#
# -----------------------------------------------------------------
#
# Topic 4:
#
# Number of reviews:  1661
# Unrelated eliminated:  1631
# Number of reviews:  30
# Duplicate eliminated:  0
# Number of reviews:  30
#
# -----------------------------------------------------------------
#
# Topic 19:
#
# Number of reviews:  1661
# Unrelated eliminated:  1631
# Number of reviews:  30
# Duplicate eliminated:  0
# Number of reviews:  30
#
# -----------------------------------------------------------------
#
# Topic 8:
#
# Number of reviews:  1661
# Unrelated eliminated:  1629
# Number of reviews:  32
# Duplicate eliminated:  0
# Number of reviews:  32
#
# -----------------------------------------------------------------
#
# Topic 17:
#
# Number of reviews:  1661
# Unrelated eliminated:  1648
# Number of reviews:  13
# Duplicate eliminated:  0
# Number of reviews:  13
#
# -----------------------------------------------------------------
#
# Topic 5:
#
# Number of reviews:  1661
# Unrelated eliminated:  1655
# Number of reviews:  6
# Duplicate eliminated:  0
# Number of reviews:  6
#
# -----------------------------------------------------------------
#
# Topic 16:
#
# Number of reviews:  1661
# Unrelated eliminated:  1658
# Number of reviews:  3
# Duplicate eliminated:  0
# Number of reviews:  3
#
# -----------------------------------------------------------------

# %%
print("\n Topics with top reviews: \n")
print(DIVIDER)
print_topics_with_reviews(topic_list)
# Out:
#  Topics with top reviews:
#
#
# -----------------------------------------------------------------
#
# Topic 3:
#
# Keywords: UPDATE TIME FORCE STATUS APP
#
# Top reviews from this topic:
#
# 0) constantly force closes.
#
# 1) i can't update my status.. -_-"
#
# 2) slower, force closes all the time, doesn't load pictures..
#
# 3) Cant update status.
#
# 4) every time i try to open the app my phone freezes.
#
# 5) since last update i cant see any pictures...
#
# 6) ever since the latest update i have not been able to view photos on the app.
#
# 7) not to mention it force closes constantly.
#
# 8) keeps crashing, forcing it to close.
#
# 9) it also won't let me upload my pictures...
#
# 10) Still won't let me log in
#
# 11) It freezes all the time and kicks me out all the time.
#
# 12) since the latest update it always says "network error"
#
# 13) at first i wasn't going to let something like being unable to upload photos on a consistent basis bother me, but then all of the force closing, network error, and lag made me want to flip a table.
#
# 14) message in facebook for android (latest version) whenever i try to reply to something from a notification; also, whenever i get this error, whatever i had typed in, disappears.
#
# 15) every time i tried to give a review, it would always come up with an error, and i'd have to retry several times to get it posted!
#
# 16) Horrible, you guys finally got it working then again you guys update it and it cant even load statuses nor pictures >:(
#
# 17) last update has made the app not load pics or graphics until several seconds, sometimes minutes, and very often not at all.
#
# 18) In order to get the latest updates on the timeline I will need to actually close and restart the app.
#
# 19) It was working great now it force closes every time I try to open it!!!!!
#
#
# -----------------------------------------------------------------
#
# Topic 9:
#
# Keywords: LOAD PICTURE TAKE LIKE SEE
#
# Top reviews from this topic:
#
# 0) takes forever to refresh or  load comments
#
# 1) it takes forever too load.
#
# 2) can't view any pictures now.
#
# 3) i can't upload pictures anymore!!!
#
# 4) Sucks ttm, takes forever to load.
#
# 5) and when it does pictures will not load!
#
# 6) pictures do not load.
#
# 7) it won't load pictures
#
# 8) no pictures load on your news feed or when you click into it.
#
# 9) takes forever to load anything, even if i'm using wifi.
#
# 10) It's slow to load, and notifications don't work properly.
#
# 11) won't load at all most of the time.
#
# 12) it wont load pictures or videos on the app..
#
# 13) images take forever to load, if at all.
#
# 14) Take forever to upload ....
#
# 15) pictures wont load!
#
# 16) it takes ages to load.
#
# 17) My FB won't even load.
#
# 18) fuckin sucks wont load
#
# 19) Can't change profile picture.
#
#
# -----------------------------------------------------------------
#
# Topic 14:
#
# Keywords: SLOW CHANGE ERROR PHOTO APP
#
# Top reviews from this topic:
#
# 0) how can i change my cover pic?
#
# 1) network error stuff
#
# 2) Very slow & crashes.
#
# 3) this app is so slow.
#
# 4) for the last week i have not been able to view any photos through my app.
#
# 5) i cannot change my cover photo fix it now
#
# 6) since the update, constant network errors.
#
# 7) Slow loading.
#
# 8) keep getting network error, wtf?!
#
# 9) Why can't I change my cover photo anymore????
#
# 10) slow loading after last update...
#
# 11) slow as turtle
#
# 12) no option for update cover photo
#
# 13) Can't change profile picture.
#
# 14) Cant upload pics %>_<%
#
# 15) so sick and tired of getting network error messages when at the same time, facebook web works fine!
#
# 16) it also still tells me network error when my connection is perfectly fine
#
# 17) Slow, problems with slow laggy updates and failure to view photos,at times.
#
# 18) after auto correct got a word wrong i went back to change it, then the app froze.
#
# 19) Needs a lot of bug fixes although it freezes a lot on s3
#
#
# -----------------------------------------------------------------
#
# Topic 2:
#
# Keywords: POST COMMENT PHOTO DELETE CANT
#
# Top reviews from this topic:
#
# 0) i cant post my status updates..
#
# 1) can't delete comments.
#
# 2) move to sd please
#
# 3) why i cannot post status and checkin on my wall?
#
# 4) Can't post comments or like anything...
#
# 5) Cant delete post.
#
# 6) I can't post status why?
#
# 7) i can't update my status, check-in or photos on my fb wall.
#
# 8) How can i remove comments???
#
# 9) Cant upload pics %>_<%
#
# 10) also, they need to make it so that you can hide posts from certain people like the website does.
#
# 11) I like the upgrade to it but HATE the fact that you cant erase your comments or others anymore thru phone.
#
# 12) they need to give me the option of moving it to my sd card, or they need to make the file smaller.
#
# 13) i can't update my status i can't look and my group comments upload photos or comment on anything.
#
# 14) My only wish for this app is to one day (ASAP) have it so we can all move it to the SD card.
#
# 15) regularly asks to find all of my phone contacts on facebook. i don't want to do this, but i can't permanently dismiss it.
#
# 16) no, facebook, i still don't want to add my phone contacts to my facebook friends.
#
# 17) I can't post on friends walls, can't like posts, photos, can't share!!!
#
# 18) i can't like, comment and tag people after i had viewed people photos...
#
# 19) can't find them (used to find with friends ) or follow comments any longer.
#
#
# -----------------------------------------------------------------
#
# Topic 12:
#
# Keywords: PHONE MUCH MEMORY TAKE SPACE
#
# Top reviews from this topic:
#
# 0) Takes up way too much of my phone storage!
#
# 1) Takes WAY too much internal memory.
#
# 2) occupies a lot of space
#
# 3) And having an HTC desire phone its already got poor phone memory without having this bugging up my space.
#
# 4) You caused me to lose 20% of my numbers because they don't sync right with low memory.
#
# 5) ive had it downloaded on my phone, had to delete it for storage space and i cleared that out before trying to install it said file is invalid or something..
#
# 6) Takes far too much space on my phone.
#
# 7) the major problem, i believe is you somehow created a memory leak.
#
# 8) it sustains so much memory very poor older ws more betr
#
# 9) takes a lot of internal memory....
#
# 10) because it's takes 32 mb in phone.
#
# 11) 4. Shuts my phone down randomly.
#
# 12) This new version takes waaaaay too much internal MB.
#
# 13) all advertisment should be gone.
#
# 14) takes up 28mb on my phone.
#
# 15) My daughter has a version that only takes a third if the memory but can't locate it in app store.
#
# 16) won't let me type without having to put my own spaces in.
#
# 17) fb takes up the most storage than any other app i have on my phone.
#
# 18) the problem is with the way items display,pics are small,large empty space e.t.c the display generally not attractive.
#
# 19) And when I leave comments and i press my thumbs at the any empty spaces, than the comments are completely gone!!
#
#
# -----------------------------------------------------------------
#
# Topic 10:
#
# Keywords: NEW FEED NEWS UPDATE SLOW
#
# Top reviews from this topic:
#
# 0) very slow loading news feed, comment and photo.
#
# 1) Very very slow to update.
#
# 2) it does not want to update my feeds.
#
# 3) The news feed shown is old...
#
# 4) New pop up windows do not imptess me when you break the rest of the app to do it.
#
# 5) news feed with unpredictable order.
#
# 6) Plus it's extremely slow to load new feeds.
#
# 7) Messenger is just too slow...
#
# 8) when i'm lucky enough for it to stay open for a little while its pretty slow and has lots of glitches!
#
# 9) i am now having old posts come back and no new posts!
#
# 10) and the new refresh feed is crap js
#
# 11) this most recent update is extremely slow.
#
# 12) New notifications are not updated immediately..
#
# 13) news feed updates have  gotten miserably slow.
#
# 14) And its slow in the news feed...
#
# 15) Takes hours to update my news feed.
#
# 16) won't load new feeds.
#
# 17) after updated, my update status doesn't appear in my wall..
#
# 18) i canot post a new status righ now..wtf is this...
#
# 19) News feed is jacked up, won't stay current.
#
#
# -----------------------------------------------------------------
#
# Topic 1:
#
# Keywords: USE FACEBOOK FB PHONE CLEAR
#
# Top reviews from this topic:
#
# 0) it crashes a lot in the background, syncs useless info to my phone, & the stuff that goes on facebook nowadays.
#
# 1) The app fails to log in and now I cannot use Facebook on my phone.
#
# 2) it's just a useless app taking up room on my phone for no reason.
#
# 3) it just stops uploading and i have to restart my phone
#
# 4) if you force shut the app after continual crashes it totally shuts down ur cellnet data connection.
#
# 5) keeps playing up freezing lots of force close coming up come on fb sort it out i use it everyday and everyday i have problems
#
# 6) Please optimize to reduce ram usage. May use up to 70mb.
#
# 7) why the hell can anyone access my android facebook account just by simply tapping on the "sign up for facebook"
#
# 8) it will sign in, but won't sync anything and won't post anything so it's basically useless for my purposes.
#
# 9) i love fb but i hate that i cant send it to the sd the memory device is almost full.
#
# 10) the bloat is unacceptable, and unnecessary.
#
# 11) I have to clear cache/data and logoff and login to update news feed.
#
# 12) weird how i can just go online to my fb page but the app won't pull it up at all
#
# 13) i love my fb but the android app seems to slow down my device and use a lot of memory...
#
# 14) it's basically good to use for uploading pics.
#
# 15) they use lot of phone memory for my mobile i.e 14mb
#
# 16) i constantly clear data, but it still crashes...
#
# 17) because facebook is use 60% of my ram free spaces.
#
# 18) It wastes battery at night when charging and not even in use!
#
# 19) facebook remains in memory after log out.
#
#
# -----------------------------------------------------------------
#
# Topic 11:
#
# Keywords: FACEBOOK OFTEN DOWNLOAD TABLET SAY
#
# Top reviews from this topic:
#
# 0) i watch youtube and use everything it was ok but why facebook say "lost connection"?!?!?!?
#
# 1) additionally, it is still not optimised for tablets and displays huge images, pages look awful.
#
# 2) said package was invalid  when i tried to download
#
# 3) hd tablet optimised app please.
#
# 4) pages freeze often.
#
# 5) facebook won't allow me to update my status on either my facebook  app or mobile site on my razr hd's browser.
#
# 6) -"facebook is not responding"
#
# 7) slowest app of any.
#
# 8) Slowest yet, says network error often, regardless of connected or disconnected to Wi-Fi.
#
# 9) I used to check in often but with this latest release it's simply impossible.
#
# 10) you're automatically taken to the mobile youtube site where it says the video cannot be played.
#
# 11) can't even download it onto my tablet
#
# 12) its just dumb that now all.of a sudden i cant download
#
# 13) It sumtimes says error coonection it sucks
#
# 14) I have to disconnect for facebook and reconnect for everything else!
#
# 15) it continues to say facebook's not responding ....
#
# 16) occasionally, the app says that the image can't be opened & please try again later.
#
# 17) it's so painful when login facebook now.....
#
# 18) download gives a warning "package file is invalid"
#
# 19) Often hangs and will have to forcr quit...
#
#
# -----------------------------------------------------------------
#
# Topic 18:
#
# Keywords: MANY HANG CONNECT FACEBOOK GAME
#
# Top reviews from this topic:
#
# 0) I cant play facebook connect games unless i m on 3/4G network.
#
# 1) Its amazing that after that many years,  photos on Facebook almost always hangs up on loading.
#
# 2) Many of my games can't progress until I connect to facebook really peeved off!!!!!!!
#
# 3) the slowest facebook application ever in the world!!!
#
# 4) Buggy, won't load, especially since there really are not too many features.
#
# 5) hangs on updating
#
# 6) when updating, it's very slow.
#
# 7) Constant crashing.
#
# 8) many times hang or stops working......
#
# 9) Why doesn't this work plz fix i can't play game cause i can't connect to Facebook
#
# 10) especially the notifications,aren't updating at all!
#
# 11) it easy to play but it hard when i log in to play other account
#
# 12) the app is slow and always hangs ...
#
# 13) Working slow HTC inspire 4g
#
# 14) i have 4g and this is so slow updating that i rarely use of.
#
# 15) slowest app ever seen...
#
# 16) hangs up with black screen, so slow..........
#
# 17) lacks many features of the regular facebook website and in addition has glitches such as loading the same 10 events one is attending over and over again rather than showing any more and differn events further in the future.
#
# 18) TOO MANY ERROR LOADING!!!
#
# 19) it stops working after my android os is upgraded....
#
#
# -----------------------------------------------------------------
#
# Topic 7:
#
# Keywords: RECENT STORY TOP SHOW SELECT
#
# Top reviews from this topic:
#
# 0) it does not want to update my feeds.
#
# 1) When I put on my preferences the I want the recent stories not the top stories it doessnt take it and it always take the top stories ugghh!
#
# 2) i don't like the fact that im forced to view my friends posts as top stories when i much rather recent stories.
#
# 3) seeing old status updates, although set to most recent.
#
# 4) Needs some serious liposuction!
#
# 5) does everything you would expect, still needs some work on the approvals for privacy confirmation process.
#
# 6) everything looks nice but when i use the most recent timeline it gives me posts form three weeks ago as most current.
#
# 7) does not properly show the most recent statuses when i selection most recent.
#
# 8) the describtion for pictures shows only three lines.
#
# 9) how come no matter how many times i select i want the statuses shown by "most recent" and not "top stories" it still wants to show them the "top stories" first??
#
# 10) most recent didn't really show most recent feed, it still show top story.
#
# 11) old posts are mixed with new ones regardless of whether i select top stories or most recent.
#
# 12) why can i hide stories or pictures?
#
# 13) i have my newsfeed set to most recent news and it keeps reverting back to top stories.
#
# 14) for one, i hate the fact i can't sort my newsfeed by most recent.
#
# 15) Everything takes ages to update and recent stories list is all over the place.
#
# 16) slow, unresponsive, and stories are mixed up even after hitting the "most recent" option.
#
# 17) the app crashes, pictures loading last to much, besides the news feed shows  "most recent" but it shows "top stories"
#
# 18) why can't select and copy the taxes in links.
#
# 19) facebook now routinely keeps showing old posts that i have made at the top of the news feed, even when most recent is selected, its been happening for the past couple of weeks.
#
#
# -----------------------------------------------------------------
#
# Topic 13:
#
# Keywords: KEEP SAYING TELLING CONNECTION AD
#
# Top reviews from this topic:
#
# 0) It keeps telling me log in failed.
#
# 1) it keeps saying "no connection"
#
# 2) keep getting network error, wtf?!
#
# 3) groups not opening properly it keeps on saying connection lost...
#
# 4) plus its telling me something is wrong with my sever and there not
#
# 5) stop the money ads
#
# 6) just keeps spinning telling me to wait.....
#
# 7) quit filling my pages with ads for products i don't want!
#
# 8) i have to type my posts twice it keeps telling me "post is null try again later"..
#
# 9) Always lost connection.
#
# 10) now that all of this garbage has been added, like ads, and a bunch of other junk, it sucks.
#
# 11) Pl ad the setting of changing languages.
#
# 12) the connection is awful and i have a 4g connection.
#
# 13) i have perfect signal and facebook keeps telling me error page
#
# 14) Why is all of a sudden i can't change my cover photo and it keeps telling me no connection or it takes forever to load.
#
# 15) now it won't even load, just keeps saying error.
#
# 16) i'm not understanding why this app keeps saying "network unavailable"
#
# 17) It freezes a lot it doesnt load it keeps on saying "no internet connection " and basicly sucks .
#
# 18) this app keeps locking up my phone.
#
# 19) application keeps freezing.
#
#
# -----------------------------------------------------------------
#
# Topic 0:
#
# Keywords: BETTER FREEZING WOULD COULD LOSING
#
# Top reviews from this topic:
#
# 0) if it would run at a reduced size or had a reasonably functional widget it wouldn't be so bad, but full screen its shocking!
#
# 1) nothing but problems since  loaded msgr .
#
# 2) the problem is that it either capitalizes every word or runs them all together.
#
# 3) i cannot log in so 1 star for now.
#
# 4) No network connection and error loading story is driving me nuts that I nearly killed ant with my head while banging my head on the table.
#
# 5) constantly freezing.
#
# 6) i gave it 2 stars cuz it loaded.
#
# 7) We have to use pc or browser everytime to download photos of our dearones .
#
# 8) should have better and faster networking signed jada
#
# 9) keeps losing conection, therefore uninstalling updates
#
# 10) then it just endlessly sits on a loading screen.
#
# 11) overall it looks better and i would give it 4 stars if it wasn't for the losing connection.
#
# 12) I was so pleased with the update about a month ago until it started freezing and losing network connection!
#
# 13) would be better if it could be moved to sd card!
#
# 14) this got to get better i'm tierd it keep freezeing i'm done installing uninstalling.
#
# 15) i get a forceclose every other time i open facebook now and it's driving me nuts...
#
# 16) this is constantly having problems loading comments.
#
# 17) freezing up daily horrible app
#
# 18) keeps closing and freezing.
#
# 19) application keeps freezing.
#
#
# -----------------------------------------------------------------
#
# Topic 15:
#
# Keywords: SCREEN BLACK GOOD BECOMES TOUCH
#
# Top reviews from this topic:
#
# 0) needed an improvement on ui for larger screens
#
# 1) ever since it upgraded, it shuts down and locks me out with a black screen for a good 10 mins.
#
# 2) But the screen seems to be a little jumpy.
#
# 3) cblack screen issue..
#
# 4) was about to write a good review until the screen started to flicker on this app..
#
# 5) if this app becomes much slower, it may very well only work in reverse...
#
# 6) screen just goes black.
#
# 7) It freezes twice a day
#
# 8) And when will the black screen when viewing images be fixed?
#
# 9) I continually experience freezing, black screens, my phone gets locked up...
#
# 10) click on app and just get a totally black screen.
#
# 11) Oh and, error 498.the past 3 days.
#
# 12) hangs up with black screen, so slow..........
#
# 13) Been getting a black screen lately...
#
# 14) notifications on phone home screen are gone.
#
# 15) The most famous Facebook stupidity of non-editable posts becomes glaringly obvious when using a touch-screen.
#
# 16) i've now had to uninstall the latest update because it intermittently stopped the touch screen working on my desire hd.
#
# 17) Many lag on screen....
#
# 18) each update becomes increasingly intrusive into your personal life.
#
# 19) for some reason facebook takes to long to load now days so it becomes very boring!!!
#
#
# -----------------------------------------------------------------
#
# Topic 6:
#
# Keywords: EVERY BAD UNINSTALL VIDEO WATCH
#
# Top reviews from this topic:
#
# 0) very very very bad version do not work correctly and do not open chat its very bad
#
# 1) Almost every time I launch it, it freezes and I have to uninstall it and reinstall it.
#
# 2) why dont i have the option to uninstall?
#
# 3) every single time i open facebook it prompts me to "find friends"
#
# 4) also every time i open it asks me if i want to search my email to find friends.
#
# 5) Will not log in forecloses every time!
#
# 6) pretty frustrating, since it happens every single time i try to watch a posted youtube video.
#
# 7) when trying to watch a youtube video through fb, the option to watch through the youtube app is gone.
#
# 8) Photos are not displaying correctly.
#
# 9) very bad and slow
#
# 10) So frustrating, pictures don't show up at all keep having to uninstall and reinstall in order to get it to work.
#
# 11) lately, every time i go into the app it prompts me to "find friends" (go through all of the contacts on my phone).
#
# 12) if i say dont sync contacts and not now, it means i dont want to find any friends!
#
# 13) however, when viewing photos, captions are not supported. i can't browse through them and read every single line.
#
# 14) Dont work most of the time and very limited on what you can do..
#
# 15) Every time I open BookFace it takes forever then it crashes.
#
# 16) it crashes every 5 minutes !
#
# 17) and constantly have to uninstall and reinstall because of none loading.
#
# 18) wont launch at all since update.
#
# 19) its really very slow evn with 3ga it works slow so bad
#
#
# -----------------------------------------------------------------
#
# Topic 4:
#
# Keywords: BATTERY DAY LIFE DRAIN HOUR
#
# Top reviews from this topic:
#
# 0) the problem is it is constantly syncing and that drains battery  uninstall for an hour and you will notice huge increase in battery life
#
# 1) it kicks me out once a day and drains my battery completely.
#
# 2) installed and installed still works at a snails pace.
#
# 3) performance is improved but kills battery fast.
#
# 4) the app is functional but after disabling it my battery life tripled.
#
# 5) Uninstsllimg updates and rootuninstalling doubled battery life overnight.
#
# 6) I used the app once and it used 15% of my battery for the day.
#
# 7) snail mode activated
#
# 8) each update becomes increasingly intrusive into your personal life.
#
# 9) i click on a fuckin image n it takes be back to pics from 5 days ago...
#
# 10) fuckin sucks wont load
#
# 11) It freezes all the time and kicks me out all the time.
#
# 12) It wastes battery at night when charging and not even in use!
#
# 13) Takes hours to update my news feed.
#
# 14) App will go for hour and not update.
#
# 15) katana always forces close.
#
# 16) This app requires most of the energy from my battery on the nexus 4, sorry guys but it is not worth it -> uninstalled!
#
# 17) What's a fuckin "katana process" that crashes facebook almost every hour now ?!!!
#
# 18) Try to make a faster and lite version which consumes less battery, RAM and cpu !!!!
#
# 19) Won't Process my Likes.
#
#
# -----------------------------------------------------------------
#
# Topic 19:
#
# Keywords: STAY CURRENT CONTENT TAB AGO
#
# Top reviews from this topic:
#
# 0) makes it really hard to talk to him when i can't even stay in it for more than a few minutes without being kicked out.
#
# 1) and, just a few minutes ago, i tried to leave my review, but even that had a problem!
#
# 2) And after about 2 minutes anytime I like something it unlikes it and restarts itself.
#
# 3) The content I am getting is older than the content that displayed just a few hours ago.
#
# 4) privacy policy confusin on purpose i'm sure.
#
# 5) News feed is jacked up, won't stay current.
#
# 6) but in my current experience i have been shut out anytime i try and attach photos to both private messages and public posts...
#
# 7) it should have multi tabs ...
#
# 8) i can't even use it any more without rolling my eyes and waiting for ut to show content.
#
# 9) it crashes every 5 minutes !
#
# 10) stays loading forever
#
# 11) something it unlikes it and goes back to the top of the page.
#
# 12) when liking statuses automatically unlikes please fix.
#
# 13) it unlikes things after i push like.
#
# 14) Whn it says u comment u go to look and make sure it posted and its not there!
#
# 15) i constantly have to shut down the app and open it again just to view a photo.
#
# 16) anytime it updates you cant see nothing on fb and you have to delete the hole app and redownload it.
#
# 17) i click on a fuckin image n it takes be back to pics from 5 days ago...
#
# 18) pictures stay blank, can't get comment boxes to work properly, ....
#
# 19) Since da f last update is crashin, force closes, slow loading content!
#
#
# -----------------------------------------------------------------
#
# Topic 8:
#
# Keywords: REFRESH NEWSFEED FIND DROID COMPUTER
#
# Top reviews from this topic:
#
# 0) will not refresh at all on my droid
#
# 1) newsfeed wong refresh!
#
# 2) impossible to find friends outside my contacts or a suggested list.
#
# 3) doesn't want to refresh at all.
#
# 4) Freezes and doesn't refresh.
#
# 5) i go to look at app data and find out it was using 204mb of cache?!
#
# 6) too much crap appearing in my newsfeed.
#
# 7) been having issues with newsfeed refresh prior to that.
#
# 8) very slow and doesn't refresh often....
#
# 9) it acts like its working but if i refresh the page or get on a computer none of my actions actually happened.
#
# 10) and the new refresh feed is crap js
#
# 11) i can force refresh and sometimes it works.
#
# 12) Status's dissapearing & doesnt refresh properly.
#
# 13) Won't work or refresh at all after last update -
#
# 14) very frustrating when over half of your newsfeed involves photos.
#
# 15) doesn't refresh and no option to edit previous posts.
#
# 16) For the DROID X Freezes and force closes all the time!
#
# 17) takes forever to refresh or  load comments
#
# 18) the latest update will not allow me to refresh anything.
#
# 19) newsfeed doesn't seem to refresh properly.
#
#
# -----------------------------------------------------------------
#
# Topic 17:
#
# Keywords: TEXT HELL SMALL 10 LOCATION
#
# Top reviews from this topic:
#
# 0) the texts were too small for my 10.1 tablet.
#
# 1) location showed when posted and now it doesn't.
#
# 2) can't turn off location tracking...
#
# 3) i too can only see text and some thumbnails.
#
# 4) what the hell happened to privacy ???
#
# 5) Slow as hell
#
# 6) click on a photo and a small loading circle whirls for infinity.
#
# 7) the font size facebook program in samsung galaxy note 10.1 is too small and do not have function to adjust font sizing.
#
# 8) slow as hell but i guess its alright!
#
# 9) and on this galaxy note 10.1 tablet from samsung nothing loads !, all i get is network errors even after i tether from my phone , so bulls**t its my network .
#
# 10) i am able to read text but i can no longer see pictures.
#
# 11) can't copy text, save puctures, or change my cover picture
#
#
# -----------------------------------------------------------------
#
# Topic 5:
#
# Keywords: SLOWLY RANDOM HOME GO RUN
#
# Top reviews from this topic:
#
# 0) Random shutdown.
#
# 1) slowly again after updated sucks!
#
# 2) photos don't upload and these updates are causing facebook to run slowly.
#
# 3) when ever i go on at a random time it will go back to my home page
#
# 4) But this app run so slowly even mw Andro has 1 Ghz.
#
#
# -----------------------------------------------------------------
#
# Topic 16:
#
# Keywords: IMMEDIATELY CLICK WHATEVER SCROLL PAGE
#
# Top reviews from this topic:
#
# 0) when i click it it offs my cellphone or whatever!!
#
# 1) I click Like and the page scrolls on it's own immediately after.
#
#
# -----------------------------------------------------------------
